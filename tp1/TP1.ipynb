# %% [markdown]
# # NoSQL - TP1
#
# ## Partie 1

# %%
# !pip3 install -r requirements.txt --quiet

# %%
import pymongo
import pandas

client = pymongo.MongoClient()
db = client.tp

# output the name of the collections in the database
print(f"Collections: {db.list_collection_names()}")
print(f"Restaurants: {db.restaurants}")

# %% [markdown]
# 1. Donner les styles de cuisine présent dans la collection

# %% [markdown]
# 2. Donner tous les grades possibles dans la base

# %% [markdown]
# 3. Compter le nombre de restaurants proposant de la cuisine française ("French")

# %% [markdown]
# 4. Compter le nombre de restaurants situés sur la rue "Central Avenue"

# %% [markdown]
# 5. Compter le nombre de restaurants ayant eu une note supérieure à 50

# %% [markdown]
# 6. Lister tous les restaurants, en n'affichant que le nom, l'immeuble et la rue

# %% [markdown]
# 7. Lister tous les restaurants nommés "Burger King" (nom et quartier uniquement)

# %% [markdown]
# 8. Lister les restaurants situés sur les rues "Union Street" ou "Union Square"

# %% [markdown]
# 9. Lister les restaurants situés au-dessus de la lattitude 40.90

# %% [markdown]
# 10. Lister les restaurants ayant eu un score de 0 et un grade "A"

# %% [markdown]
# ## Partie 2

# %% [markdown]
# 1. Quelles sont les 10 plus grandes chaînes de restaurants (i.e les restaurants avec un nom identique) ?

# %% [markdown]
# 2. Donner le Top 5 et le Flop 5 des types de cuisine, en terme de nombre de restaurants.

# %% [markdown]
# 3. Quelles sont les 10 rues avec le plus de restaurants ?

# %% [markdown]
# 4. Quelles sont les rues situées sur strictement plus de 2 quartiers ? Ajouter le nom des quartiers de chaque rue.

# %% [markdown]
# 5. Lister par quartier le nombre de restaurants et le score moyen.

# %% [markdown]
# 6. Donner les dates de début et de fin des évaluations

# %% [markdown]
# 7. Quels sont les 10 restaurants (nom, quartier, addresse et score) avec le plus petit score moyen ?
